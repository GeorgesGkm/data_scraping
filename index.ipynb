# %%
# Installation de librairies
# !pip install BeautifulSoup4
# !pip install requests
# !pip install pandas
# Out:
# ...
#   Using cached numpy-2.1.1-cp311-cp311-win_amd64.whl.metadata (59 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.6 MB 2.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.6 MB 4.0 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.6 MB 6.4 MB/s eta 0:00:02
#    --------------------- ------------------ 6.3/11.6 MB 7.9 MB/s eta 0:00:01
#    ------------------------ --------------- 7.1/11.6 MB 7.0 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 7.6 MB/s eta 0:00:00
# Using cached numpy-2.1.1-cp311-cp311-win_amd64.whl (12.9 MB)
# ...

# %%
# importation 
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://books.toscrape.com/'

# %%
# la methods Get pour recupere la contenue de la page
response = requests.get(url)

#Parser le contenu HTML avec BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

#trouver les elements de livre
books = soup.find_all('article', class_ = 'product_pod')

#Initialiser des listes pour stocker les informations des livres
titles = []
prices = []
availabilities = []

# Parcourir chaque livre et extraire les information souhaiter
for book in books:
    title = book.h3.a['title']
    titles.append(title)
    
    price = book.find('p', class_='price_color').text
    prices.append('price')
    
    availability = book.find('p', class_='instock availability').text.strip()
    availabilities.append(availability)

# %%
#creer un dataFrame à partir des listes 
data = {
    'Title' : titles,
    'Price' : prices,
    'Availability' : availabilities
}

# %%
df  = pd.DataFrame(data)
df.head()
# Out:
#                                                 Title  Price Availability
# 0                                A Light in the Attic  price     In stock
# 1                                  Tipping the Velvet  price     In stock
# 2                                          Soumission  price     In stock
# 3                                       Sharp Objects  price     In stock
# 4               Sapiens: A Brief History of Humankind  price     In stock
# 5                                     The Requiem Red  price     In stock
# 6   The Dirty Little Secrets of Getting Your Dream...  price     In stock
# 7   The Coming Woman: A Novel Based on the Life of...  price     In stock
# 8   The Boys in the Boat: Nine Americans and Their...  price     In stock
# 9                                     The Black Maria  price     In stock
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  price     In stock
# 11                              Shakespeare's Sonnets  price     In stock
# ...
